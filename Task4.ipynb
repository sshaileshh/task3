# %%
import pandas as pd

# %%
sheet_id = '17OF-FQQT_R6K2TiemV6Ka2yvHJc4ZCSlSKaDZT6u0L4'   
df = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv")
df.head()
# Out:
#      Brand               Reference Google Search Code           Category  \
# 0  O'NEILL   0A4972-9950 BLACK AOP        0A4972-9950            Sandals
# 1  O'NEILL    9P1070-5056 Ink Blue        9P1070-5056            Jackets
# 2  O'NEILL  9P1070-6077 Winter Mos        9P1070-6077            Jackets
# 3  O'NEILL    8P1072-5056 Ink Blue        8P1072-5056  Jackets Technical
# 4  O'NEILL   8P1072-5112 Surf Blue        8P1072-5112  Jackets Technical
#
#                     Name  Product Page URL  Price(Euros)
# 0  FB ARCH PRINT SANDALS               NaN           NaN
# 1       LB CHARGER PARKA               NaN           NaN
# 2       LB CHARGER PARKA               NaN           NaN
# 3      LB TRANSIT JACKET               NaN           NaN
# 4      LB TRANSIT JACKET               NaN           NaN

# %%
print(df.isnull().sum())
# Out:
# Brand                   0
# Reference               0
# Google Search Code      0
# Category                0
# Name                    0
# Product Page URL      129
# Price(Euros)          129
# dtype: int64

# %%
df.rename(columns={'Product Page URL':'URL', 'Price(Euros)':'Price_in_Euros'}, inplace=True)
df.head()
# Out:
#      Brand               Reference Google Search Code           Category  \
# 0  O'NEILL   0A4972-9950 BLACK AOP        0A4972-9950            Sandals
# 1  O'NEILL    9P1070-5056 Ink Blue        9P1070-5056            Jackets
# 2  O'NEILL  9P1070-6077 Winter Mos        9P1070-6077            Jackets
# 3  O'NEILL    8P1072-5056 Ink Blue        8P1072-5056  Jackets Technical
# 4  O'NEILL   8P1072-5112 Surf Blue        8P1072-5112  Jackets Technical
#
#                     Name  URL  Price_in_Euros
# 0  FB ARCH PRINT SANDALS  NaN             NaN
# 1       LB CHARGER PARKA  NaN             NaN
# 2       LB CHARGER PARKA  NaN             NaN
# 3      LB TRANSIT JACKET  NaN             NaN
# 4      LB TRANSIT JACKET  NaN             NaN

# %%
df[df.Category == 'Sandals']
# Out:
#       Brand               Reference Google Search Code Category  \
# 0   O'NEILL   0A4972-9950 BLACK AOP        0A4972-9950  Sandals
# 87  O'NEILL   0A9970-3121 Mandarine        0A9970-3121  Sandals
# 88  O'NEILL  0A9972-5950 BLUE AOP W        0A9972-5950  Sandals
# 89  O'NEILL   0A9972-6960 GREEN AOP        0A9972-6960  Sandals
#
#                       Name                                                URL  \
# 0    FB ARCH PRINT SANDALS  https://www.oneill.com/fr/fr/arch-print-sandal...
# 87        FG DITSY SANDALS  https://www.oneill.com/nl/nl/ditsy-sandals/0A9...
# 88  FG WOVEN STRAP SANDALS  https://www.oneill.com/de/de/woven-sandals/0A9...
# 89  FG WOVEN STRAP SANDALS  https://www.oneill.com/be/nl/woven-sandals/0A9...
#
#     Price_in_Euros
# 0              NaN
# 87             NaN
# 88             NaN
# 89             NaN

# %%
a=df[df.Category == 'Sandals']
len(a)
sandal_code = ('0A4972-9950','0A9970-3121','0A9972-5950','0A9972-6960')
#result1=resource.list(q='0A4972-9950', cx='d71f3e7e0be176b5f').execute()
#result87=resource.list(q='0A9970-3121', cx='d71f3e7e0be176b5f').execute()
#result88=resource.list(q='0A9972-5950', cx='d71f3e7e0be176b5f').execute()
result89=resource.list(q='0A9972-6960', cx='d71f3e7e0be176b5f').execute()
for item in result89['items']:
    print(item['link'])
# Out:
# https://www.oneill.com/gb/en/woven-sandals/0A9972-6960-301.html
# https://www.oneill.com/eu/fr/woven-sandals/0A9972-6960-301.html
# https://www.oneill.com/eu/de/woven-sandals/0A9972-6960-32.html
# https://www.oneill.com/nl/nl/woven-sandals/0A9972-6960-301.html
# https://www.oneill.com/be/nl/woven-sandals/0A9972-6960-32.html?channable=e127160.MEE5OTcyLTY5NjAtMzI

# %%
link89 = item['link']
url = df.URL
url[89] = link89
# Out:
# <ipython-input-198-4a85339b1a7e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[89] = link89

# %%
df[df.Category == 'Jackets']
# Out:
#       Brand               Reference Google Search Code Category  \
# 1   O'NEILL    9P1070-5056 Ink Blue        9P1070-5056  Jackets
# 2   O'NEILL  9P1070-6077 Winter Mos        9P1070-6077  Jackets
# 97  O'NEILL   9P6070-3000 Gun Metal        9P6070-3000  Jackets
# 98  O'NEILL  9P6070-3021 Neon Flame        9P6070-3021  Jackets
#
#                      Name                                                URL  \
# 1        LB CHARGER PARKA  https://www.oneill.com/be/nl/charger-parka-jac...
# 2        LB CHARGER PARKA  https://www.oneill.com/nl/nl/charger-parka-jac...
# 97  LG CB TRANSIT TOURING  https://www.oneill.com/fr/fr/transit-touring-j...
# 98  LG CB TRANSIT TOURING  https://www.oneill.com/fr/be/transit-touring-j...
#
#     Price_in_Euros
# 1              NaN
# 2              NaN
# 97             NaN
# 98             NaN

# %%
result1=resource.list(q='9P1070-5056', cx='d71f3e7e0be176b5f').execute()
result2=resource.list(q='9P1070-6077', cx='d71f3e7e0be176b5f').execute()
result97=resource.list(q='9P6070-3000', cx='d71f3e7e0be176b5f').execute()
result98=resource.list(q='9P6070-3021', cx='d71f3e7e0be176b5f').execute()
for item in result98['items']:
    print(item['link'])
# Out:
# https://www.oneill.com/eu/en/transit-touring-jacket/9P6070-3021-116.html
# https://www.oneill.com/eu/en/transit-touring-jacket/9P6070-3021-128.html
# https://www.oneill.com/nl/nl/transit-touring-jacket/9P6070-3021-104.html
# https://www.oneill.com/de/de/transit-touring-jacket/9P6070-3021-104.html
# https://www.oneill.com/fr/be/transit-touring-jacket/9P6070-3021-128.html

# %%
link = item['link']
url = df.URL
#url[1] = link
#url[2] = link
#url[97] = link
url[98] = link
# Out:
# <ipython-input-218-de99ebfa3240>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[98] = link

# %%
df[df.Category == 'Jackets Technical']
# Out:
#      Brand              Reference Google Search Code           Category  \
# 3  O'NEILL   8P1072-5056 Ink Blue        8P1072-5056  Jackets Technical
# 4  O'NEILL  8P1072-5112 Surf Blue        8P1072-5112  Jackets Technical
#
#                 Name                                                URL  \
# 3  LB TRANSIT JACKET  https://www.oneill.com/be/nl/woven-sandals/0A9...
# 4  LB TRANSIT JACKET                                                NaN
#
#    Price_in_Euros
# 3             NaN
# 4             NaN

# %%
result98=resource.list(q='8P1072-5056', cx='d71f3e7e0be176b5f').execute()
for item in result98['items']:
    print(item['link'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-8c487e8468cb> in <module>
#       1 result98=resource.list(q='8P1072-5056', cx='d71f3e7e0be176b5f').execute()
# ----> 2 for item in result98['items']:
#       3     print(item['link'])
#
# KeyError: 'items'

# %%
df[df.Category == 'Pants']
# Out:
#      Unnamed: 0    Brand               Reference Google Search Code Category  \
# 5             5  O'NEILL  0A2780-1250 Light Auth        0A2780-1250    Pants
# 6             6  O'NEILL  0A2782-1250 Light Auth        0A2782-1250    Pants
# 7             7  O'NEILL       9P2772-5204 Scale        9P2772-5204    Pants
# 8             8  O'NEILL  0A2776-1250 Light Auth        0A2776-1250    Pants
# 99           99  O'NEILL    0A7782-3124 Lollipop        0A7782-3124    Pants
# 100         100  O'NEILL   0A7782-4920 PINK-PURP        0A7782-4920    Pants
# 101         101  O'NEILL  0A7790-1250 Light Auth        0A7790-1250    Pants
# 102         102  O'NEILL  0A7786-1250 Light Auth        0A7786-1250    Pants
# 103         103  O'NEILL       0A7774-5204 Scale        0A7774-5204    Pants
# 104         104  O'NEILL  0A7774-8001 Silver Mel        0A7774-8001    Pants
# 105         105  O'NEILL  9P7772-4048 Bridal Ros        9P7772-4048    Pants
#
#                               Name  \
# ...

# %%
#result5=resource.list(q='0A2780-1250', cx='d71f3e7e0be176b5f').execute()
#result6=resource.list(q='0A2782-1250', cx='d71f3e7e0be176b5f').execute()
#result7=resource.list(q='9P2772-5204', cx='d71f3e7e0be176b5f').execute()
#result8=resource.list(q='0A2776-1250', cx='d71f3e7e0be176b5f').execute()
#result99=resource.list(q='0A7782-3124', cx='d71f3e7e0be176b5f').execute()
#result=resource.list(q='0A7782-4920', cx='d71f3e7e0be176b5f').execute()
#result101=resource.list(q='0A7790-1250', cx='d71f3e7e0be176b5f').execute()
#result102=resource.list(q='0A7786-1250	', cx='d71f3e7e0be176b5f').execute()
#result103=resource.list(q='0A7774-5204', cx='d71f3e7e0be176b5f').execute()
#result104=resource.list(q='0A7774-8001', cx='d71f3e7e0be176b5f').execute()
result105=resource.list(q='9P7772-4048', cx='d71f3e7e0be176b5f').execute()
for item in result105['items']:
    print(item['link'])
# Out:
# https://www.oneill.com/eu/en/milla-sweatpants/9P7772-4048-152.html
# https://www.oneill.com/at/en/milla-sweatpants/9P7772-4048-104.html
# https://www.oneill.com/de/de/milla-sweatpants/9P7772-4048-152.html
# https://www.oneill.com/eu/nl/milla-sweatpants/9P7772-4048-104.html
# https://www.oneill.com/fr/fr/milla-sweatpants/9P7772-4048-140.html

# %%
link = item['link']
url = df.URL
url[105] = link
# Out:
# <ipython-input-32-f558fdcff41c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[105] = link

# %%
df[df.Category == 'Shorts']
# Out:
#      Unnamed: 0    Brand               Reference Google Search Code Category  \
# 9             9  O'NEILL  0A2570-6077 Winter Mos        0A2570-6077   Shorts
# 10           10  O'NEILL  0A2570-7507 Chateau Be        0A2570-7507   Shorts
# 11           11  O'NEILL   0A2570-9010 Black Out        0A2570-9010   Shorts
# 12           12  O'NEILL    0A2572-5056 Ink Blue        0A2572-5056   Shorts
# 13           13  O'NEILL  0A2572-5209 Walton Blu        0A2572-5209   Shorts
# 14           14  O'NEILL  0A2572-6077 Winter Mos        0A2572-6077   Shorts
# 15           15  O'NEILL   0A2572-6920 GREEN AOP        0A2572-6920   Shorts
# 16           16  O'NEILL   0A2572-9980 BLACK AOP        0A2572-9980   Shorts
# 17           17  O'NEILL    0A2576-5056 Ink Blue        0A2576-5056   Shorts
# 18           18  O'NEILL   0A2578-6920 GREEN AOP        0A2578-6920   Shorts
# 19           19  O'NEILL  0A2582-6151 Salina Gre        0A2582-6151   Shorts
# ...

# %%
result=resource.list(q='0A7580-4960', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(item['link'])
# Out:
# https://www.oneill.com/de/en/woven-summer-shorts/0A7580-4960-104.html
# https://www.oneill.com/fr/fr/woven-summer-shorts/0A7580-4960-104.html
# https://www.oneill.com/de/de/summer-shorts/0A7580-4960-116.html?channable=e96832.MEE3NTgwLTQ5NjAtMTE2
# https://www.oneill.com/fr/be/woven-summer-shorts/0A7580-4960-116.html?channable=e96832.MEE3NTgwLTQ5NjAtMTE2
# https://www.oneill.com/nl/nl/woven-summer-shorts/0A7580-4960-104.html

# %%
link = item['link']
url = df.URL
url[110] = link
# Out:
# <ipython-input-79-7a41e4defaa8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[110] = link

# %%
df[df.Category == 'Superfleeces']
# Out:
#      Unnamed: 0    Brand               Reference Google Search Code  \
# 21           21  O'NEILL   9P1174-6900 GREEN AOP        9P1174-6900
# 113         113  O'NEILL  9P6170-3021 Neon Flame        9P6170-3021
# 114         114  O'NEILL   9P6174-6900 GREEN AOP        9P6174-6900
#
#          Category                        Name  \
# 21   Superfleeces  LB SHERPA HZ HOODIE - CAMO
# 113  Superfleeces        LG ANISA SUPERFLEECE
# 114  Superfleeces  LG SHERPA HZ HOODIE - CAMO
#
#                                                    URL  Price_in_Euros
# 21   https://www.oneill.com/fr/fr/sherpa-camo-half-...             NaN
# 113  https://www.oneill.com/de/de/anisa-superfleece...             NaN
# 114  https://www.oneill.com/nl/nl/sherpa-camo-half-...             NaN

# %%
price=df.Price_in_Euros
price[113] = 49.99
# Out:
# <ipython-input-233-67e6f3ce06f7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price[113] = 49.99

# %%
result=resource.list(q='9P1174-6900', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(result['items'])
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-234-faab8aae821b> in <module>
# ----> 1 result=resource.list(q='9P1174-6900', cx='d71f3e7e0be176b5f').execute()
#       2 for item in result['items']:
#       3     print(result['items'])
#
# c:\users\lenovo\appdata\local\programs\python\python38-32\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# c:\users\lenovo\appdata\local\programs\python\python38-32\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     905             callback(resp)
#     906         if resp.status >= 300:
# ...

# %%
link = item['link']
url = df.URL
url[114] = link
# Out:
# <ipython-input-87-2251a2158a5c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[114] = link

# %%
df[df.Category == 'Sweatshirts']
# Out:
#      Unnamed: 0  Unnamed: 0.1    Brand               Reference  \
# 22           22            22  O'NEILL    8P1482-5056 Ink Blue
# 23           23            23  O'NEILL   8P3662-9010 Black Out
# 24           24            24  O'NEILL   9P1476-6900 GREEN AOP
# 25           25            25  O'NEILL   9P1476-9900 BLACK AOP
# 26           26            26  O'NEILL     9P1478-8026 Asphalt
# 27           27            27  O'NEILL  8P1478-6077 Winter Mos
# 28           28            28  O'NEILL       0A1490-5204 Scale
# 29           29            29  O'NEILL  0A1490-6096 Amazon Gre
# 30           30            30  O'NEILL   0A1488-6920 GREEN AOP
# 115         115           115  O'NEILL    0A6474-6082 Lily Pad
# 116         116           116  O'NEILL  0A6474-8101 White Mele
# 117         117           117  O'NEILL    8P6480-8900 GREY AOP
# 118         118           118  O'NEILL  9P6470-4048 Bridal Ros
#
#     Google Search Code     Category                            Name  \
# ...

# %%
price=df.Price_in_Euros
price[22] = 49.99
# Out:
# <ipython-input-228-7e9989c61264>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price[22] = 49.99

# %%
result=resource.list(q='8P1482-5056', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(result['items'])
# Out:
# [{'kind': 'customsearch#result', 'title': "The O'Neill Ride Sweatshirt", 'htmlTitle': 'The O&#39;Neill Ride Sweatshirt', 'link': 'https://www.oneill.com/nl/en/the-oneill-ride-sweatshirt/8P1482.html?cgid=boys-discover-new-collection-fall-winter&dwvar_8P1482_color=5056', 'displayLink': 'www.oneill.com', 'snippet': '8P1482. Delivery within 1-2 days. Free Delivery over €40. Free returns. Buy now, \npay later. Sign up for our newsletter. Find a store · Facebook Instagram\xa0...', 'htmlSnippet': '<b>8P1482</b>. Delivery within 1-2 days. Free Delivery over €40. Free returns. Buy now, <br>\npay later. Sign up for our newsletter. Find a store &middot; Facebook Instagram&nbsp;...', 'cacheId': 'ra9vTLZETk4J', 'formattedUrl': 'https://www.oneill.com/nl/en/the.../8P1482.html?...8P1482...5056', 'htmlFormattedUrl': 'https://www.oneill.com/nl/en/the.../<b>8P1482</b>.html?...<b>8P1482</b>...<b>5056</b>', 'pagemap': {'offer': [{'pricecurrency': 'EUR', 'price': '49.99'}, {'pricecurrency': 'EUR', 'price
# ...

# %%
link = item['link']
url = df.URL
url[118] = link
# Out:
# <ipython-input-114-35585fe48e99>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[118] = link

# %%
df[df.Category == 'Tees']
# Out:
#      Unnamed: 0  Unnamed: 0.1    Brand               Reference  \
# 31           31            31  O'NEILL  8P2176-6058 Forest Nig
# 32           32            32  O'NEILL  0A2476-1030 Powder Whi
# 33           33            33  O'NEILL  0A2476-8001 Silver Mel
# 34           34            34  O'NEILL  0A2482-5930 BLUE AOP W
# 35           35            35  O'NEILL  0A2482-5950 BLUE AOP W
# 36           36            36  O'NEILL  0A2496-2533 Spicy Oran
# 37           37            37  O'NEILL   0A2496-6910 GREEN AOP
# 38           38            38  O'NEILL   0A2496-6920 GREEN AOP
# 39           39            39  O'NEILL   9A2478-9010 Black Out
# 40           40            40  O'NEILL  9A2482-2523 Burning Or
# 119         119           119  O'NEILL  0A7272-1030 Powder Whi
# 120         120           120  O'NEILL       0A7272-5204 Scale
# 121         121           121  O'NEILL       0A7280-4540 Marge
# 122         122           122  O'NEILL  0A7280-6151 Salina Gre
# ...

# %%
price=df.Price_in_Euros
price[32] = 17.99
# Out:
# <ipython-input-203-d5ce86d8d2f9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price[32] = 17.99

# %%
result=resource.list(q='0A2476-1030', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(result['items'])
# Out:
# [{'kind': 'customsearch#result', 'title': "Horizon Pocket T-Shirt O'Neill", 'htmlTitle': 'Horizon Pocket T-Shirt O&#39;Neill', 'link': 'https://www.oneill.com/eu/en/horizon-pocket-t-shirt/0A2476-1030-104.html', 'displayLink': 'www.oneill.com', 'snippet': '0A2476-1030-104; Wash Instructions: Free Delivery over €100. 60 day free \nreturn policy. Sign up for our newsletter. Find a store · Facebook Instagram \nYoutube\xa0...', 'htmlSnippet': '<b>0A2476</b>-<b>1030</b>-104; Wash Instructions: Free Delivery over €100. 60 day free <br>\nreturn policy. Sign up for our newsletter. Find a store &middot; Facebook Instagram <br>\nYoutube&nbsp;...', 'cacheId': '9bmpmkzG_xsJ', 'formattedUrl': 'https://www.oneill.com/eu/en/horizon-pocket-t.../0A2476-1030-104.html', 'htmlFormattedUrl': 'https://www.oneill.com/eu/en/horizon-pocket-t.../<b>0A2476</b>-<b>1030</b>-104.html', 'pagemap': {'offer': [{'pricecurrency': 'EUR', 'price': '17.99'}, {'pricecurrency': 'EUR', 'price': '17.99'}], 'cse_thumbnail': [{
# ...

# %%
link = item['link']
url = df.URL
url[127] = link
# Out:
# <ipython-input-153-be6eb4e34417>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[127] = link

# %%
df[df.Category == 'Boardshorts']
# Out:
#     Unnamed: 0  Unnamed: 0.1    Brand               Reference  \
# 41          41            41  O'NEILL    0A3274-5900 BLUE AOP
# 42          42            42  O'NEILL   0A3276-6920 GREEN AOP
# 43          43            43  O'NEILL    0A3280-5900 BLUE AOP
# 44          44            44  O'NEILL   0A3288-3121 Mandarine
# 45          45            45  O'NEILL  9A3278-5014 Dazzling B
# 46          46            46  O'NEILL    0A3172-8900 GREY AOP
#
#    Google Search Code     Category                      Name  \
# 41        0A3274-5900  Boardshorts       PB DOUBLE-UP SHORTS
# 42        0A3276-6920  Boardshorts         PB STACKED SHORTS
# 43        0A3280-5900  Boardshorts         PB HORIZON SHORTS
# 44        0A3288-3121  Boardshorts            PB CALI SHORTS
# 45        9A3278-5014  Boardshorts            PB VERT SHORTS
# 46        0A3172-8900  Boardshorts  PB HYPERFREAK HEIST LINE
#
#                                                   URL  Price_in_Euros
# ...

# %%
price=df.Price_in_Euros
price[41] = 45.99
# Out:
# <ipython-input-170-1a9da2a8fd28>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price[41] = 45.99

# %%
result=resource.list(q='0A3274-5900', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(result['items'])
# Out:
# [{'kind': 'customsearch#result', 'title': "Double-Up Swim Shorts O'Neill", 'htmlTitle': 'Double-Up Swim Shorts O&#39;Neill', 'link': 'https://www.oneill.com/eu/en/double-up-swim-shorts/0A3274-5900-128.html', 'displayLink': 'www.oneill.com', 'snippet': '0A3274-5900-128; Wash Instructions: Free Delivery over €100. 60 day free \nreturn policy. Sign up for our newsletter. Find a store · Facebook Instagram \nYoutube\xa0...', 'htmlSnippet': '<b>0A3274</b>-<b>5900</b>-128; Wash Instructions: Free Delivery over €100. 60 day free <br>\nreturn policy. Sign up for our newsletter. Find a store &middot; Facebook Instagram <br>\nYoutube&nbsp;...', 'cacheId': 'BPJx-VCD6zAJ', 'formattedUrl': 'https://www.oneill.com/eu/en/double-up-swim.../0A3274-5900-128.html', 'htmlFormattedUrl': 'https://www.oneill.com/eu/en/double-up-swim.../<b>0A3274</b>-<b>5900</b>-128.html', 'pagemap': {'offer': [{'pricecurrency': 'EUR', 'price': '45.99'}, {'pricecurrency': 'EUR', 'price': '45.99'}], 'cse_thumbnail': [{'src': 
# ...

# %%
link = item['link']
url = df.URL
url[46] = link
# Out:
# <ipython-input-167-c0dc7549620e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[46] = link

# %%
df[df.Category == 'Fleeces']
# Out:
#     Unnamed: 0  Unnamed: 0.1    Brand               Reference  \
# 47          47            47  O'NEILL   8P0274-5112 Surf Blue
# 48          48            48  O'NEILL  8P0274-6058 Forest Nig
# 49          49            49  O'NEILL  9P0270-6058 Forest Nig
# 50          50            50  O'NEILL  9P0272-5075 Seaport Bl
# 51          51            51  O'NEILL  9P0274-6058 Forest Nig
# 52          52            52  O'NEILL   9P0274-9010 Black Out
# 53          53            53  O'NEILL  9P0276-6058 Forest Nig
# 95          95            95  O'NEILL  9P5270-1030 Powder Whi
# 96          96            96  O'NEILL  9P5270-4048 Bridal Ros
#
#    Google Search Code Category                       Name  \
# 47        8P0274-5112  Fleeces          PB JACK FZ FLEECE
# 48        8P0274-6058  Fleeces          PB JACK FZ FLEECE
# 49        9P0270-6058  Fleeces  PB HOODED FULL ZIP FLEECE
# 50        9P0272-5075  Fleeces         PB FULL-ZIP FLEECE
# ...

# %%
price=df.Price_in_Euros
price[96] = 49.99
# Out:
# <ipython-input-157-45792c434066>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price[96] = 49.99

# %%
result=resource.list(q='9P5270-4048', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(result['items'])
# Out:
# [{'kind': 'customsearch#result', 'title': "Hazel Fleece O'Neill", 'htmlTitle': 'Hazel Fleece O&#39;Neill', 'link': 'https://www.oneill.com/eu/en/hazel-fleece/9P5270-4048-116.html', 'displayLink': 'www.oneill.com', 'snippet': '9P5270-4048-116; Wash Instructions: Free Delivery over €100. 60 day free \nreturn policy. Sign up for our newsletter. Find a store · Facebook Instagram \nYoutube\xa0...', 'htmlSnippet': '<b>9P5270</b>-<b>4048</b>-116; Wash Instructions: Free Delivery over €100. 60 day free <br>\nreturn policy. Sign up for our newsletter. Find a store &middot; Facebook Instagram <br>\nYoutube&nbsp;...', 'cacheId': 'll7CKJg71x4J', 'formattedUrl': 'https://www.oneill.com/eu/en/hazel-fleece/9P5270-4048-116.html', 'htmlFormattedUrl': 'https://www.oneill.com/eu/en/hazel-fleece/<b>9P5270</b>-<b>4048</b>-116.html', 'pagemap': {'offer': [{'pricecurrency': 'EUR', 'price': '49.99'}, {'pricecurrency': 'EUR', 'price': '49.99'}], 'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/i
# ...

# %%
link = item['link']
url = df.URL
url[96] = link
# Out:
# <ipython-input-187-03b276a4949e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[96] = link

# %%
df[df.Category == 'Jackets Snow']
# Out:
#     Unnamed: 0  Unnamed: 0.1    Brand               Reference  \
# 54          54            54  O'NEILL    8P0084-5056 Ink Blue
# 55          55            55  O'NEILL   8P0084-5112 Surf Blue
# 56          56            56  O'NEILL  8P3648-6025 DRESDEN BL
# 57          57            57  O'NEILL  8P3648-6058 Forest Nig
# 58          58            58  O'NEILL   8P3648-9010 Black Out
# 59          59            59  O'NEILL  9P0074-5075 Seaport Bl
# 60          60            60  O'NEILL  9P0074-6058 Forest Nig
# 61          61            61  O'NEILL  9P0078-6058 Forest Nig
# 62          62            62  O'NEILL   9P0078-9010 Black Out
# 63          63            63  O'NEILL    9P0080-5900 BLUE AOP
# 64          64            64  O'NEILL   9P0080-6900 GREEN AOP
# 65          65            65  O'NEILL   9P0080-6960 GREEN AOP
# 66          66            66  O'NEILL   9P0080-9900 BLACK AOP
# 67          67            67  O'NEILL  9P0082-5075 Seaport Bl
#
# ...

# %%
price=df.Price_in_Euros
price[54] = 99.99
# Out:
# <ipython-input-137-43f4761e3bb4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price[54] = 99.99

# %%
result=resource.list(q='8P0084-5056', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(result['items'])
# Out:
# [{'kind': 'customsearch#result', 'title': "Statement Ski / Snowboard Jacket O'Neill", 'htmlTitle': 'Statement Ski / Snowboard Jacket O&#39;Neill', 'link': 'https://www.oneill.com/nl/en/statement-ski-snowboard-jacket/8P0084-5056-128.html', 'displayLink': 'www.oneill.com', 'snippet': '8P0084-5056-128; Wash Instructions: Free Delivery over €75. 60 day free return \npolicy. Sign up for our newsletter. Find a store · Facebook Instagram Youtube\xa0...', 'htmlSnippet': '<b>8P0084</b>-<b>5056</b>-128; Wash Instructions: Free Delivery over €75. 60 day free return <br>\npolicy. Sign up for our newsletter. Find a store &middot; Facebook Instagram Youtube&nbsp;...', 'cacheId': 'W0AEMRG4hRcJ', 'formattedUrl': 'https://www.oneill.com/nl/en/statement-ski.../8P0084-5056-128.html', 'htmlFormattedUrl': 'https://www.oneill.com/nl/en/statement-ski.../<b>8P0084</b>-<b>5056</b>-128.html', 'pagemap': {'offer': [{'pricecurrency': 'EUR', 'price': '99.99'}, {'pricecurrency': 'EUR', 'price': '99.99'}], 'cse_th
# ...

# %%
link = item['link']
url = df.URL
url[67] = link
# Out:
# <ipython-input-217-2981c00231cd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[67] = link

# %%
df[df.Category == 'Snow pants']
# Out:
#     Unnamed: 0  Unnamed: 0.1    Brand               Reference  \
# 68          68            68  O'NEILL    8P3070-5056 Ink Blue
# 69          69            69  O'NEILL  8P3072-2521 Bright Ora
# 70          70            70  O'NEILL   8P3072-5112 Surf Blue
# 71          71            71  O'NEILL  8P3072-6017 Treetop Gr
# 72          72            72  O'NEILL  8P3072-6025 DRESDEN BL
# 73          73            73  O'NEILL  8P3658-2521 Bright Ora
# 74          74            74  O'NEILL  8P3658-6025 DRESDEN BL
# 75          75            75  O'NEILL   8P3658-9010 Black Out
# 76          76            76  O'NEILL  9P3070-6058 Forest Nig
# 77          77            77  O'NEILL   9P3070-9010 Black Out
# 78          78            78  O'NEILL  9P3072-2518 Citrine Or
# 79          79            79  O'NEILL  9P3072-5075 Seaport Bl
# 80          80            80  O'NEILL  9P3072-6058 Forest Nig
# 81          81            81  O'NEILL   9P3072-9010 Black Out
#
# ...

# %%
price=df.Price_in_Euros
price[68] = 119.99
# Out:
# <ipython-input-127-3c7f2d87be59>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price[68] = 119.99

# %%
result=resource.list(q='8P3070-5056', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(result['items'])
# Out:
# [{'kind': 'customsearch#result', 'title': "Bib Ski / Snowboard Pants O'Neill", 'htmlTitle': 'Bib Ski / Snowboard Pants O&#39;Neill', 'link': 'https://www.oneill.com/eu/en/bib-ski-snowboard-pants/8P3070-5056-128.html', 'displayLink': 'www.oneill.com', 'snippet': '8P3070-5056-128; Wash Instructions: Free Delivery over €100. 60 day free \nreturn policy. Sign up for our newsletter. Find a store · Facebook Instagram \nYoutube\xa0...', 'htmlSnippet': '<b>8P3070</b>-<b>5056</b>-128; Wash Instructions: Free Delivery over €100. 60 day free <br>\nreturn policy. Sign up for our newsletter. Find a store &middot; Facebook Instagram <br>\nYoutube&nbsp;...', 'cacheId': 'XWMVdH6AVLsJ', 'formattedUrl': 'https://www.oneill.com/eu/en/bib-ski-snowboard.../8P3070-5056-128.html', 'htmlFormattedUrl': 'https://www.oneill.com/eu/en/bib-ski-snowboard.../<b>8P3070</b>-<b>5056</b>-128.html', 'pagemap': {'offer': [{'pricecurrency': 'EUR', 'price': '119.99'}, {'pricecurrency': 'EUR', 'price': '119.99'}], 'cse_thu
# ...

# %%
link = item['link']
url = df.URL
url[81] = link
# Out:
# <ipython-input-21-3f663533fcdb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[81] = link

# %%
df[df.Category == 'Accessories']
# Out:
#     Unnamed: 0  Unnamed: 0.1    Brand               Reference  \
# 82          82            82  O'NEILL  9P9270-4048 Bridal Ros
#
#    Google Search Code     Category                 Name  \
# 82        9P9270-4048  Accessories  BG WOOL SCARF GIRLS
#
#                                                   URL  Price_in_Euros
# 82  https://www.oneill.com/de/de/wool-scarf/9P9270...           25.99

# %%
price=df.Price_in_Euros
price[82] = 25.99
# Out:
# <ipython-input-98-2ed811780a65>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price[82] = 25.99

# %%
result=resource.list(q='9P9270-4048	', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(result['items'])
# Out:
# [{'kind': 'customsearch#result', 'title': "Wool Scarf O'Neill", 'htmlTitle': 'Wool Scarf O&#39;Neill', 'link': 'https://www.oneill.com/eu/en/wool-scarf/9P9270-4048-0.html', 'displayLink': 'www.oneill.com', 'snippet': '9P9270-4048-0; Wash Instructions: Free Delivery over €100. 60 day free return \npolicy. Sign up for our newsletter. Find a store · Facebook Instagram Youtube\xa0...', 'htmlSnippet': '<b>9P9270</b>-<b>4048</b>-0; Wash Instructions: Free Delivery over €100. 60 day free return <br>\npolicy. Sign up for our newsletter. Find a store &middot; Facebook Instagram Youtube&nbsp;...', 'cacheId': 'wXVUzWMT3eYJ', 'formattedUrl': 'https://www.oneill.com/eu/en/wool-scarf/9P9270-4048-0.html', 'htmlFormattedUrl': 'https://www.oneill.com/eu/en/wool-scarf/<b>9P9270</b>-<b>4048</b>-0.html', 'pagemap': {'offer': [{'pricecurrency': 'EUR', 'price': '25.99'}, {'pricecurrency': 'EUR', 'price': '25.99'}], 'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRix3VeeHmr
# ...

# %%
link = item['link']
url = df.URL
url[82] = link
# Out:
# <ipython-input-25-06d64e1470f6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[82] = link

# %%
df[df.Category == 'Bags']
# Out:
#     Unnamed: 0  Unnamed: 0.1    Brand               Reference  \
# 83          83            83  O'NEILL  0A9070-7507 Chateau Be
#
#    Google Search Code Category                Name  \
# 83        0A9070-7507     Bags  BG BEACH BAG STRAW
#
#                                                   URL  Price_in_Euros
# 83  https://www.oneill.com/nl/nl/beach-staw-bag/0A...           29.99

# %%
price=df.Price_in_Euros
price[83] = 29.99
# Out:
# <ipython-input-95-2946cc2983d3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price[83] = 29.99

# %%
result=resource.list(q='0A9070-7507', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(result['items'])
# Out:
# [{'kind': 'customsearch#result', 'title': "Beach Staw Bag O'Neill", 'htmlTitle': 'Beach Staw Bag O&#39;Neill', 'link': 'https://www.oneill.com/eu/en/beach-staw-bag/0A9070-7507-0.html', 'displayLink': 'www.oneill.com', 'snippet': '0A9070-7507-0; Wash Instructions: Free Delivery over €100. 60 day free return \npolicy. Sign up for our newsletter. Find a store · Facebook Instagram Youtube\xa0...', 'htmlSnippet': '<b>0A9070</b>-<b>7507</b>-0; Wash Instructions: Free Delivery over €100. 60 day free return <br>\npolicy. Sign up for our newsletter. Find a store &middot; Facebook Instagram Youtube&nbsp;...', 'cacheId': 'Ld-fqh6EKwIJ', 'formattedUrl': 'https://www.oneill.com/eu/en/beach-staw-bag/0A9070-7507-0.html', 'htmlFormattedUrl': 'https://www.oneill.com/eu/en/beach-staw-bag/<b>0A9070</b>-<b>7507</b>-0.html', 'pagemap': {'offer': [{'pricecurrency': 'EUR', 'price': '29.99'}, {'pricecurrency': 'EUR', 'price': '29.99'}], 'cse_thumbnail': [{'src': 'https://encrypted-tbn1.gstatic.com/images?q=
# ...

# %%
result['items']
# Out:
# [{'kind': 'customsearch#result',
#   'title': "Venice Beach-Party Bikini Set O'Neill",
#   'htmlTitle': 'Venice Beach-Party Bikini Set O&#39;Neill',
#   'link': 'https://www.oneill.com/nl/en/venice-beach-party-bikini-set/0A8372-6940-104.html',
#   'displayLink': 'www.oneill.com',
#   'snippet': '0A8372-6940-104; Wash Instructions: Free Delivery over €75. 60 day free return \npolicy. Sign up for our newsletter. Find a store · Facebook Instagram Youtube\xa0...',
#   'htmlSnippet': '<b>0A8372</b>-<b>6940</b>-104; Wash Instructions: Free Delivery over €75. 60 day free return <br>\npolicy. Sign up for our newsletter. Find a store &middot; Facebook Instagram Youtube&nbsp;...',
#   'cacheId': 'Fr4Ki0YaAYwJ',
#   'formattedUrl': 'https://www.oneill.com/nl/en/venice-beach...set/0A8372-6940-104.html',
#   'htmlFormattedUrl': 'https://www.oneill.com/nl/en/venice-beach...set/<b>0A8372</b>-<b>6940</b>-104.html',
#   'pagemap': {'offer': [{'pricecurrency': 'EUR', 'price': '29.99'},
# ...

# %%
result=resource.list(q='0A9070-7507	', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(item['link'])
# Out:
# https://www.oneill.com/eu/en/beach-staw-bag/0A9070-7507-0.html
# https://www.oneill.com/nl/en/beach-staw-bag/0A9070.html
# https://www.oneill.com/de/de/beach-staw-bag/0A9070-7507-0.html
# https://www.oneill.com/eu/fr/beach-staw-bag/0A9070-7507-0.html
# https://www.oneill.com/nl/nl/beach-staw-bag/0A9070-7507-0.html

# %%
link = item['link']
url = df.URL
url[83] = link
# Out:
# <ipython-input-28-01d0cf871705>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[83] = link

# %%
df[df.Category == 'Headwear']
# Out:
#     Unnamed: 0  Unnamed: 0.1    Brand               Reference  \
# 84          84            84  O'NEILL    9P9172-6149 Bivaline
# 85          85            85  O'NEILL  9P9174-3021 Neon Flame
# 86          86            86  O'NEILL  0A9170-7507 Chateau Be
#
#    Google Search Code  Category                   Name  \
# 84        9P9172-6149  Headwear  BG POP-MELANGE BEANIE
# 85        9P9174-3021  Headwear    BG SOFT-KNIT BEANIE
# 86        0A9170-7507  Headwear          BG FEDORA HAT
#
#                                                   URL  Price_in_Euros
# 84  https://www.oneill.com/de/de/pop-melange-beani...           25.99
# 85  https://www.oneill.com/de/de/soft-knit-beanie/...           22.99
# 86  https://www.oneill.com/nl/nl/fedora-hat/0A9170...           25.99

# %%
price=df.Price_in_Euros
price[84] = 2.99
# Out:
# <ipython-input-88-0a245a38d338>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price[84] = 25.99

# %%
result=resource.list(q='9P9172-6149', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(result['items'])
# Out:
# [{'kind': 'customsearch#result', 'title': "Pop-Melange Beanie O'Neill", 'htmlTitle': 'Pop-Melange Beanie O&#39;Neill', 'link': 'https://www.oneill.com/eu/en/pop-melange-beanie/9P9172-6149-0.html', 'displayLink': 'www.oneill.com', 'snippet': '9P9172-6149-0; Wash Instructions: Free Delivery over €100. 60 day free return \npolicy. Sign up for our newsletter. Find a store · Facebook Instagram Youtube\xa0...', 'htmlSnippet': '<b>9P9172</b>-<b>6149</b>-0; Wash Instructions: Free Delivery over €100. 60 day free return <br>\npolicy. Sign up for our newsletter. Find a store &middot; Facebook Instagram Youtube&nbsp;...', 'cacheId': 'Ekoa-_A0o_QJ', 'formattedUrl': 'https://www.oneill.com/eu/en/pop-melange-beanie/9P9172-6149-0.html', 'htmlFormattedUrl': 'https://www.oneill.com/eu/en/pop-melange-beanie/<b>9P9172</b>-<b>6149</b>-0.html', 'pagemap': {'offer': [{'pricecurrency': 'EUR', 'price': '25.99'}, {'pricecurrency': 'EUR', 'price': '25.99'}], 'cse_thumbnail': [{'src': 'https://encrypted-tbn0.g
# ...

# %%
link = item['link']
url = df.URL
url[86] = link
# Out:
# <ipython-input-35-9306fac8db09>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[86] = link

# %%
df[df.Category == 'Dresses & Jumpsuits']
# Out:
#     Unnamed: 0  Unnamed: 0.1    Brand               Reference  \
# 90          90            90  O'NEILL   0A8986-4920 PINK-PURP
# 91          91            91  O'NEILL       0A8986-5204 Scale
# 92          92            92  O'NEILL    0A8971-4900 PINK AOP
# 93          93            93  O'NEILL   0A8988-1940 WHITE AOP
# 94          94            94  O'NEILL  0A8988-4960 PINK AOP W
#
#    Google Search Code             Category                   Name  \
# 90        0A8986-4920  Dresses & Jumpsuits         LG SWEAT DRESS
# 91        0A8986-5204  Dresses & Jumpsuits         LG SWEAT DRESS
# 92        0A8971-4900  Dresses & Jumpsuits  LG LOLA TUNIQUE DRESS
# 93        0A8988-1940  Dresses & Jumpsuits     LG SUMMER PLAYSUIT
# 94        0A8988-4960  Dresses & Jumpsuits     LG SUMMER PLAYSUIT
#
#                                                   URL  Price_in_Euros
# 90  https://www.oneill.com/de/de/hooded-side-zip-s...           69.99
# ...

# %%
price=df.Price_in_Euros
price[90] = 69.99
# Out:
# <ipython-input-81-4c2ccab950fa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price[90] = 69.99

# %%
result=resource.list(q='0A8986-4920', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(result['items'])
# Out:
# [{'kind': 'customsearch#result', 'title': "Hooded Side Zip Sweater Dress O'Neill", 'htmlTitle': 'Hooded Side Zip Sweater Dress O&#39;Neill', 'link': 'https://www.oneill.com/de/en/hooded-side-zip-sweater-dress/0A8986-4920-104.html', 'displayLink': 'www.oneill.com', 'snippet': '0A8986-4920-104; Wash Instructions: Free Delivery over €75. 60 day free return \npolicy. Sign up for our newsletter. Find a store · Facebook Instagram Youtube\xa0...', 'htmlSnippet': '<b>0A8986</b>-<b>4920</b>-104; Wash Instructions: Free Delivery over €75. 60 day free return <br>\npolicy. Sign up for our newsletter. Find a store &middot; Facebook Instagram Youtube&nbsp;...', 'cacheId': 'p6ZKLkkC6U8J', 'formattedUrl': 'https://www.oneill.com/de/en/hooded-side-zip.../0A8986-4920-104.html', 'htmlFormattedUrl': 'https://www.oneill.com/de/en/hooded-side-zip.../<b>0A8986</b>-<b>4920</b>-104.html', 'pagemap': {'offer': [{'pricecurrency': 'EUR', 'price': '69.99'}, {'pricecurrency': 'EUR', 'price': '69.99'}], 'cse_thumb
# ...

# %%
link = item['link']
url = df.URL
url[94] = link
# Out:
# <ipython-input-46-af142d29b218>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[94] = link

# %%
df[df.Category == 'Skirts']
# Out:
#      Unnamed: 0  Unnamed: 0.1    Brand              Reference  \
# 111         111           111  O'NEILL  0A7870-4920 PINK-PURP
# 112         112           112  O'NEILL      0A7870-5204 Scale
#
#     Google Search Code Category             Name  \
# 111        0A7870-4920   Skirts  LG RUFFLE SKIRT
# 112        0A7870-5204   Skirts  LG RUFFLE SKIRT
#
#                                                    URL  Price_in_Euros
# 111  https://www.oneill.com/nl/nl/branded-waistband...           39.99
# 112  https://www.oneill.com/nl/nl/branded-waistband...           39.99

# %%
price=df.Price_in_Euros
price[111] = 39.99
# Out:
# <ipython-input-70-8c301ea9f862>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price[111] = 39.99

# %%
result=resource.list(q='0A7870-4920	', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(item['link'])
# Out:
# https://www.oneill.com/de/en/branded-waistband-ruffle-skirt/0A7870-4920-128.html
# https://www.oneill.com/fr/fr/branded-waistband-ruffle-skirt/0A7870-4920-128.html
# https://www.oneill.com/de/de/branded-waistband-ruffle-skirt/0A7870-4920-128.html
# https://www.oneill.com/nl/nl/branded-waistband-ruffle-skirt/0A7870-4920-104.html

# %%
result['items']
# Out:
# [{'kind': 'customsearch#result',
#   'title': "Branded Waistband Ruffle Skirt O'Neill",
#   'htmlTitle': 'Branded Waistband Ruffle Skirt O&#39;Neill',
#   'link': 'https://www.oneill.com/de/en/branded-waistband-ruffle-skirt/0A7870-4920-128.html',
#   'displayLink': 'www.oneill.com',
#   'snippet': '0A7870-4920-128; Wash Instructions: Free Delivery over €75. 60 day free return \npolicy. Sign up for our newsletter. Find a store · Facebook Instagram Youtube\xa0...',
#   'htmlSnippet': '<b>0A7870</b>-<b>4920</b>-128; Wash Instructions: Free Delivery over €75. 60 day free return <br>\npolicy. Sign up for our newsletter. Find a store &middot; Facebook Instagram Youtube&nbsp;...',
#   'cacheId': 'WuN36o1fbCwJ',
#   'formattedUrl': 'https://www.oneill.com/de/en/branded-waistband.../0A7870-4920-128.html',
#   'htmlFormattedUrl': 'https://www.oneill.com/de/en/branded-waistband.../<b>0A7870</b>-<b>4920</b>-128.html',
#   'pagemap': {'offer': [{'pricecurrency': 'EUR', 'price': '39.99'},
# ...

# %%
link = item['link']
url = df.URL
url[112] = link
# Out:
# <ipython-input-51-a2c07352e923>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[112] = link

# %%
df[df.Category == 'Bikinis']
# Out:
#      Unnamed: 0  Unnamed: 0.1    Brand              Reference  \
# 128         128           128  O'NEILL  0A8372-6940 GREEN AOP
#
#     Google Search Code Category                          Name  \
# 128        0A8372-6940  Bikinis  PG VENICE BEACH-PARTY BIKINI
#
#                                                    URL  Price_in_Euros
# 128  https://www.oneill.com/eu/de/venice-beach-part...           29.99

# %%
price=df.Price_in_Euros
price[128] = 29.99
# Out:
# <ipython-input-62-6cd6c89cff65>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price[128] = 29.99

# %%
result=resource.list(q='0A8372-6940	', cx='d71f3e7e0be176b5f').execute()
for item in result['items']:
    print(item['link'])
# Out:
# https://www.oneill.com/nl/en/venice-beach-party-bikini-set/0A8372-6940-104.html
# https://www.oneill.com/fr/be/venice-beach-party-bikini-set/0A8372-6940-104.html
# https://www.oneill.com/nl/nl/venice-beach-party-bikini-set/0A8372-6940-104.html
# https://www.oneill.com/be/nl/venice-beach-party-bikini-set/0A8372-6940-128.html
# https://www.oneill.com/eu/de/venice-beach-party-bikini-set/0A8372-6940-128.html

# %%
link = item['link']
url = df.URL
url[128] = link
# Out:
# <ipython-input-54-401eb6984a49>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url[128] = link

# %% [markdown]
# ## Creating custom search engine: ##

# %%
api_key = 'AIzaSyCMw0Fd5j9mofiIzED4Nz-JEJBNm2TaEIE'

# %%
from apiclient.discovery import build

# %%
resource = build('customsearch', 'v1', developerKey=api_key).cse()

# %%
result=resource.list(q='0A2570-7507', cx='d71f3e7e0be176b5f').execute()

# %%
for item in result['items']:
    print(item['link'])
# Out:
# https://www.oneill.com/de/en/friday-night-chino-shorts/0A2570-7507-128.html
# https://www.oneill.com/be/nl/friday-night-chino-shorts/0A2570-7507-104.html
# https://www.oneill.com/fr/fr/friday-night-chino-shorts/0A2570-7507-128.html
# https://www.oneill.com/de/de/friday-night-chino-shorts/0A2570-7507-128.html
# https://www.oneill.com/fr/nl/friday-night-chino-shorts/0A2570-7507-104.html

# %%
link=item['link']
link
# Out:
# 'https://www.oneill.com/fr/nl/friday-night-chino-shorts/0A2570-7507-104.html'

# %%
url=df.Product_Page_URL

# %%
a=df[df.Category == 'Sandals']
len(a)
# Out:
# 4

# %%
df = pd.read_csv('task_4.csv')
df
# Out:
#      Unnamed: 0  Unnamed: 0.1    Brand               Reference  \
# 0             0             0  O'NEILL   0A4972-9950 BLACK AOP
# 1             1             1  O'NEILL    9P1070-5056 Ink Blue
# 2             2             2  O'NEILL  9P1070-6077 Winter Mos
# 3             3             3  O'NEILL    8P1072-5056 Ink Blue
# 4             4             4  O'NEILL   8P1072-5112 Surf Blue
# ..          ...           ...      ...                     ...
# 124         124           124  O'NEILL   0A7383-1940 WHITE AOP
# 125         125           125  O'NEILL  0A7383-4960 PINK AOP W
# 126         126           126  O'NEILL  8P7170-3350 Neon Tange
# 127         127           127  O'NEILL    0A7392-6082 Lily Pad
# 128         128           128  O'NEILL   0A8372-6940 GREEN AOP
#
#     Google Search Code           Category                            Name  \
# 0          0A4972-9950            Sandals           FB ARCH PRINT SANDALS
# ...

# %%
df.to_csv('TASK-04.csv')

# %%
pd.read_csv('TASK-04.csv')
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    Brand  \
# 0             0             0               0  O'NEILL
# 1             1             1               1  O'NEILL
# 2             2             2               2  O'NEILL
# 3             3             3               3  O'NEILL
# 4             4             4               4  O'NEILL
# ..          ...           ...             ...      ...
# 124         124           124             124  O'NEILL
# 125         125           125             125  O'NEILL
# 126         126           126             126  O'NEILL
# 127         127           127             127  O'NEILL
# 128         128           128             128  O'NEILL
#
#                   Reference Google Search Code           Category  \
# 0     0A4972-9950 BLACK AOP        0A4972-9950            Sandals
# 1      9P1070-5056 Ink Blue        9P1070-5056            Jackets
# 2    9P1070-6077 Winter Mos        9P1070-6077            Jackets
# ...
